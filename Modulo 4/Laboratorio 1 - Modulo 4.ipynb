# %%
import pandas as pd
import datetime
#Trasacciones del genero Masculino
t_m = pd.read_csv('TransaccionesM.csv')
t_m = t_m.drop(t_m.columns[0], axis=1)
t_m
# Out:
#        Customer ID      Name   Surname Gender   Birthdate  Transaction Amount  \
# 0           305449     Jacob  Williams      M  1981-10-25              115.97
# 1           988259    Nathan    Snyder      M  1977-10-26               11.31
# 2           504238    Denise    Porter      M  1957-10-31               77.73
# 3           924841  Kimberly      Ball      M  1976-10-26              928.68
# 4           123235    Hunter    Peters      M  1971-10-28              387.78
# ...            ...       ...       ...    ...         ...                 ...
# 22235       366368   Christy    Wagner      M  1988-10-23              255.70
# 22236       728409    Debbie   Griffin      M  1994-10-22             2000.82
# 22237        91701    Joseph    Lawson      M  1985-10-24             1228.36
# 22238       133285    Nicole  Franklin      M  1979-10-26              464.29
# 22239       616122     Maria    Keller      M  1981-10-25              472.57
#
# ...

# %%
#transacciones del genero femenino
t_f= pd.read_csv('TransaccionesF.csv')
t_f = t_f.drop(t_f.columns[0], axis=1)
t_f
# Out:
#        Customer ID       Name    Surname Gender   Birthdate  \
# 0           752858       Sean  Rodriguez      F  2002-10-20
# 1            26381   Michelle     Phelps    NaN  1985-10-24
# 2           764762    Crystal      Knapp      F  1951-11-02
# 3           576539     Monica   Bartlett      F  2001-10-20
# 4           124681     Thomas       Shaw    NaN  1976-10-26
# ...            ...        ...        ...    ...         ...
# 27755       754013  Katherine      Avery      F  1961-10-30
# 27756       197066     George     Cooper      F  1998-10-21
# 27757       891845  Christine      Leach      F  1997-10-21
# 27758       800560       Anna      Allen      F  1999-10-21
# 27759       832184      Billy     Walker      F  1958-10-31
#
#        Transaction Amount        Date              Merchant Name     Category
# 0                   35.47  2023-04-03              Smith-Russell     Cosmetic
# 1                 2552.72  2023-07-17     Peck, Spence and Young       Travel
# ...

# %%
#cambiando el formato de fecha a los dataframe
#Dataframe Masculino
t_m['Birthdate'] = pd.to_datetime(t_m['Birthdate'],format='%Y-%m-%d')
t_m['Birthdate'] = t_m['Birthdate'].dt.strftime('%d/%m/%Y')
t_m['Date'] = pd.to_datetime(t_m['Date'],format='%Y-%m-%d')
t_m['Date'] = t_m['Date'].dt.strftime('%d/%m/%Y')
t_m
# Out:
#        Customer ID      Name   Surname Gender   Birthdate  Transaction Amount  \
# 0           305449     Jacob  Williams      M  25/10/1981              115.97
# 1           988259    Nathan    Snyder      M  26/10/1977               11.31
# 2           504238    Denise    Porter      M  31/10/1957               77.73
# 3           924841  Kimberly      Ball      M  26/10/1976              928.68
# 4           123235    Hunter    Peters      M  28/10/1971              387.78
# ...            ...       ...       ...    ...         ...                 ...
# 22235       366368   Christy    Wagner      M  23/10/1988              255.70
# 22236       728409    Debbie   Griffin      M  22/10/1994             2000.82
# 22237        91701    Joseph    Lawson      M  24/10/1985             1228.36
# 22238       133285    Nicole  Franklin      M  26/10/1979              464.29
# 22239       616122     Maria    Keller      M  25/10/1981              472.57
#
# ...

# %%
#Dataframe Femenino
t_f['Birthdate'] = pd.to_datetime(t_f['Birthdate'],format='%Y-%m-%d')
t_f['Birthdate'] = t_f['Birthdate'].dt.strftime('%d/%m/%Y')
t_f['Date'] = pd.to_datetime(t_f['Date'],format='%Y-%m-%d')
t_f['Date'] = t_f['Date'].dt.strftime('%d/%m/%Y')
t_f
# Out:
#        Customer ID       Name    Surname Gender   Birthdate  \
# 0           752858       Sean  Rodriguez      F  20/10/2002
# 1            26381   Michelle     Phelps    NaN  24/10/1985
# 2           764762    Crystal      Knapp      F  02/11/1951
# 3           576539     Monica   Bartlett      F  20/10/2001
# 4           124681     Thomas       Shaw    NaN  26/10/1976
# ...            ...        ...        ...    ...         ...
# 27755       754013  Katherine      Avery      F  30/10/1961
# 27756       197066     George     Cooper      F  21/10/1998
# 27757       891845  Christine      Leach      F  21/10/1997
# 27758       800560       Anna      Allen      F  21/10/1999
# 27759       832184      Billy     Walker      F  31/10/1958
#
#        Transaction Amount        Date              Merchant Name     Category
# 0                   35.47  03/04/2023              Smith-Russell     Cosmetic
# 1                 2552.72  17/07/2023     Peck, Spence and Young       Travel
# ...

# %%
#Hacemos la concatenacion de los dos Dataframes
consolidado_transacciones = pd.concat([t_m,t_f], axis=0)
consolidado_transacciones
# Out:
#        Customer ID       Name   Surname Gender   Birthdate  \
# 0           305449      Jacob  Williams      M  25/10/1981
# 1           988259     Nathan    Snyder      M  26/10/1977
# 2           504238     Denise    Porter      M  31/10/1957
# 3           924841   Kimberly      Ball      M  26/10/1976
# 4           123235     Hunter    Peters      M  28/10/1971
# ...            ...        ...       ...    ...         ...
# 27755       754013  Katherine     Avery      F  30/10/1961
# 27756       197066     George    Cooper      F  21/10/1998
# 27757       891845  Christine     Leach      F  21/10/1997
# 27758       800560       Anna     Allen      F  21/10/1999
# 27759       832184      Billy    Walker      F  31/10/1958
#
#        Transaction Amount        Date               Merchant Name    Category
# 0                  115.97  20/09/2023                  Steele Inc    Clothing
# 1                   11.31  11/01/2023  Wilson, Wilson and Russell    Cosmetic
# ...

# %%
#Generar un tercer dataframe con una llave comun quepermita unificar o  mezclar
df_index = consolidado_transacciones.set_index('Category')
df_index
# Out:
#             Customer ID       Name   Surname Gender   Birthdate  \
# Category
# Clothing         305449      Jacob  Williams      M  25/10/1981
# Cosmetic         988259     Nathan    Snyder      M  26/10/1977
# Restaurant       504238     Denise    Porter      M  31/10/1957
# Travel           924841   Kimberly      Ball      M  26/10/1976
# Market           123235     Hunter    Peters      M  28/10/1971
# ...                 ...        ...       ...    ...         ...
# Restaurant       754013  Katherine     Avery      F  30/10/1961
# Market           197066     George    Cooper      F  21/10/1998
# Market           891845  Christine     Leach      F  21/10/1997
# Cosmetic         800560       Anna     Allen      F  21/10/1999
# Market           832184      Billy    Walker      F  31/10/1958
#
#             Transaction Amount        Date               Merchant Name
# Category
# Clothing                115.97  20/09/2023                  Steele Inc
# ...
