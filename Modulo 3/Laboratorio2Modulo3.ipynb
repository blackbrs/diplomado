# %%
import pandas as pd
datos_muertes =  pd.read_csv(r"D:\Diplomado\Laboratorios\Modulo 3\MuertesEstadosUnidos.csv")
datos_muertes
# Out:
#          Unnamed: 0  resident_status  education_2003_revision  month_of_death  \
# 0                 0                1                      3.0               1
# 1                 1                1                      6.0               1
# 2                 2                1                      3.0               1
# 3                 3                1                      3.0               1
# 4                 4                1                      5.0               1
# ...             ...              ...                      ...             ...
# 2718193     2718193                1                      1.0               5
# 2718194     2718194                1                      9.0              12
# 2718195     2718195                4                      9.0              12
# 2718196     2718196                4                      9.0               7
# 2718197     2718197                1                      9.0              12
#
#         sex  age_recode_12  place_of_death_and_decedents_status  \
# 0         M             10                                    1
# 1         M              9                                    1
# 2         F             11                                    4
# 3         F              6                                    4
# 4         F             11                                    6
# ...      ..            ...                                  ...
# 2718193   M              1                                    7
# 2718194   F              7                                    4
# 2718195   M              5                                    1
# 2718196   M             10                                    1
# 2718197   M             10                                    4
#
#         marital_status  day_of_week_of_death injury_at_work  358_cause_recode  \
# 0                    M                     1              U               230
# 1                    M                     2              U                93
# 2                    W                     6              U               189
# 3                    S                     5              N               434
# 4                    W                     5              U               214
# ...                ...                   ...            ...               ...
# 2718193              S                     7              U               358
# 2718194              U                     6              U               215
# 2718195              U                     1              U               178
# 2718196              U                     7              U               214
# 2718197              U                     2              U               207
#
#          race  hispanic_origin
# 0           1              100
# 1           1              100
# 2           1              100
# 3           3              100
# 4           1              100
# ...       ...              ...
# 2718193     2              998
# 2718194     1              100
# 2718195     1              299
# 2718196     2              100
# 2718197     2              998
#
# [2718198 rows x 13 columns]

# %%
#CONATANDO CLOLUMNAS Y FILAS
datos_muertes =  open("D:\Diplomado\Laboratorios\Modulo 3\MuertesEstadosUnidos.csv",'r')

# %%
#RUTINA QUE CUENTA LAS FILAS Y COLUMNA DE DATOS
#leemos la primera linea para obtener los nombres de las columnas
cols = datos_muertes.readline().strip().split(",")
cols
# Out:
# ['',
#  'resident_status',
#  'education_2003_revision',
#  'month_of_death',
#  'sex',
#  'age_recode_12',
#  'place_of_death_and_decedents_status',
#  'marital_status',
#  'day_of_week_of_death',
#  'injury_at_work',
#  '358_cause_recode',
#  'race',
#  'hispanic_origin']

# %%
# Ahora el puntero del archivo está al comienzo de la segunda línea, por lo que puedes contar las filas correctamente
num_filas = 0
for lineas in datos_muertes:
    num_filas += 1

# Imprime el número de filas y columnas
print("El archivo contiene un numero  {} filas y {} columnas".format(num_filas, len(cols)))
# Out:
# El archivo contiene un numero  2718198 filas y 13 columnas

# %%
#Transformacion de datos parquet y 
datos_muertes =  pd.read_csv(r"D:\Diplomado\Laboratorios\Modulo 3\MuertesEstadosUnidos.csv")
datos_muertes.to_parquet("D:\Diplomado\Laboratorios\Modulo 3\MuertesEstadosUnidos.gzip", compression='gzip')
datos_muertes.to_json("D:\Diplomado\Laboratorios\Modulo 3\MuertesEstadosUnidos.js",orient="split")

# %%
pd.read_parquet("D:\Diplomado\Laboratorios\Modulo 3\MuertesEstadosUnidos.gzip")
# Out:
#           number  resident_status  education_2003_revision  month_of_death  \
# 0              0                1                      3.0               1
# 1              1                1                      6.0               1
# 2              2                1                      3.0               1
# 3              3                1                      3.0               1
# 4              4                1                      5.0               1
# ...          ...              ...                      ...             ...
# 2718193  2718193                1                      1.0               5
# 2718194  2718194                1                      9.0              12
# 2718195  2718195                4                      9.0              12
# 2718196  2718196                4                      9.0               7
# 2718197  2718197                1                      9.0              12
#
#         sex  age_recode_12  place_of_death_and_decedents_status  \
# 0         M             10                                    1
# 1         M              9                                    1
# 2         F             11                                    4
# 3         F              6                                    4
# 4         F             11                                    6
# ...      ..            ...                                  ...
# 2718193   M              1                                    7
# 2718194   F              7                                    4
# 2718195   M              5                                    1
# 2718196   M             10                                    1
# 2718197   M             10                                    4
#
#         marital_status  day_of_week_of_death injury_at_work  358_cause_recode  \
# 0                    M                     1              U               230
# 1                    M                     2              U                93
# 2                    W                     6              U               189
# 3                    S                     5              N               434
# 4                    W                     5              U               214
# ...                ...                   ...            ...               ...
# 2718193              S                     7              U               358
# 2718194              U                     6              U               215
# 2718195              U                     1              U               178
# 2718196              U                     7              U               214
# 2718197              U                     2              U               207
#
#          race  hispanic_origin
# 0           1              100
# 1           1              100
# 2           1              100
# 3           3              100
# 4           1              100
# ...       ...              ...
# 2718193     2              998
# 2718194     1              100
# 2718195     1              299
# 2718196     2              100
# 2718197     2              998
#
# [2718198 rows x 13 columns]

# %%
pd.read_json("D:\Diplomado\Laboratorios\Modulo 3\MuertesEstadosUnidos.js",orient="split")
# Out:
#           number  resident_status  education_2003_revision  month_of_death  \
# 0              0                1                      3.0               1
# 1              1                1                      6.0               1
# 2              2                1                      3.0               1
# 3              3                1                      3.0               1
# 4              4                1                      5.0               1
# ...          ...              ...                      ...             ...
# 2718193  2718193                1                      1.0               5
# 2718194  2718194                1                      9.0              12
# 2718195  2718195                4                      9.0              12
# 2718196  2718196                4                      9.0               7
# 2718197  2718197                1                      9.0              12
#
#         sex  age_recode_12  place_of_death_and_decedents_status  \
# 0         M             10                                    1
# 1         M              9                                    1
# 2         F             11                                    4
# 3         F              6                                    4
# 4         F             11                                    6
# ...      ..            ...                                  ...
# 2718193   M              1                                    7
# 2718194   F              7                                    4
# 2718195   M              5                                    1
# 2718196   M             10                                    1
# 2718197   M             10                                    4
#
#         marital_status  day_of_week_of_death injury_at_work  358_cause_recode  \
# 0                    M                     1              U               230
# 1                    M                     2              U                93
# 2                    W                     6              U               189
# 3                    S                     5              N               434
# 4                    W                     5              U               214
# ...                ...                   ...            ...               ...
# 2718193              S                     7              U               358
# 2718194              U                     6              U               215
# 2718195              U                     1              U               178
# 2718196              U                     7              U               214
# 2718197              U                     2              U               207
#
#          race  hispanic_origin
# 0           1              100
# 1           1              100
# 2           1              100
# 3           3              100
# 4           1              100
# ...       ...              ...
# 2718193     2              998
# 2718194     1              100
# 2718195     1              299
# 2718196     2              100
# 2718197     2              998
#
# [2718198 rows x 13 columns]
